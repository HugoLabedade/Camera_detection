# %%
import cv2
from ultralytics import YOLO
import torch


device = "cuda" if torch.cuda.is_available() else "cpu"
print(f'Using device: {device}')

#Load the YOLOv8 model
model = YOLO(r'C:\Users\hugol\Desktop\projet_fin_annee\fil_rouge_deep_learning\Camera_detection\runs\detect\train19\weights\best.pt')
#model = YOLO('./yolov8n.pt')
model.to(device)

# Open the video file
video_path = "states.mp4"

#results = model.track(source=video_path, show=True)
# Out:
# Using device: cuda
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 10
#       7 print(f'Using device: {device}')
#       9 #Load the YOLOv8 model
# ---> 10 model = YOLO(r'C:\Users\hugol\Desktop\projet_fin_annee\fil_rouge_deep_learning\Camera_detection\runs\detect\train19\weights\best.pt')
#      11 #model = YOLO('./yolov8n.pt')
#      12 model.to(device)
#
# File c:\Users\hugol\.conda\envs\deep_learning\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\hugol\.conda\envs\deep_learning\Lib\site-packages\ultralytics\engine\model.py:151, in Model.__init__(self, model, task, verbose)
# ...

# %%
import cv2
from ultralytics import YOLO
import torch



#model.conf = 0.5

# Function to calculate Intersection over Union (IoU)
def bbox_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])

    intersection = max(0, x2 - x1 + 1) * max(0, y2 - y1 + 1)

    box1_area = (box1[2] - box1[0] + 1) * (box1[3] - box1[1] + 1)
    box2_area = (box2[2] - box2[0] + 1) * (box2[3] - box2[1] + 1)

    union = box1_area + box2_area - intersection

    iou = intersection / union
    return iou

# Open the video file
video_path = "./neggers.mp4"
cap = cv2.VideoCapture(video_path)

# Initialize variables for tracking
prev_detections = []

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Check for overlapping bounding boxes
        #if len(results.xyxy[0]) > 1:  # At least two detections
        #    for i in range(len(results.xyxy[0])):
        #        for j in range(i + 1, len(results.xyxy[0])):
        #            box1 = results.xyxy[0][i][0:4]
        #            box2 = results.xyxy[0][j][0:4]
        #            iou = bbox_iou(box1, box2)
        #            if iou > 0.5:  # You can adjust this threshold as needed
        #                print("Bounding boxes overlap!")

        # Display the annotated frame
        annotated_frame = results[0].plot()
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        key = cv2.waitKey(30)
        if key == 27:
            break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# ...
